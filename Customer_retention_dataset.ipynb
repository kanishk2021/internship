# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("customer_retention_dataset.xlsx")

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
df.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %% [markdown]
# # data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
col=df.columns
col
for i in col[0:]:
    print(i)
    plt.figure()
    sns.countplot(data=df,y=i)
    plt.show()
# Out:
# 1Gender of respondent
# 2 How old are you?
# 3 Which city do you shop online from?
# 4 What is the Pin Code of where you shop online from?
# 5 Since How Long You are Shopping Online ?
# 6 How many times you have made an online purchase in the past 1 year?
# 7 How do you access the internet while shopping on-line?
# 8 Which device do you use to access the online shopping?
# 9 What is the screen size of your mobile device?
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# 10 What is the operating system (OS) of your device?
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
# ...

# %%
#checking correlation
df.corr()
# Out:
#                                                     4 What is the Pin Code of where you shop online from?
# 4 What is the Pin Code of where you shop online...                                                1.0

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df,x='4 What is the Pin Code of where you shop online from?',y="Which of the Indian online retailer would you recommend to a friend?")
plt.show()

# %%
sns.scatterplot(data=df,x='1Gender of respondent'
,y="Which of the Indian online retailer would you recommend to a friend?")
plt.show()

# %%
sns.displot(df['1Gender of respondent'])

# %%
sns.displot(df['18 The content on the website must be easy to read and understand'])

# %%
sns.displot(df['47 Getting value for money spent'])

# %%
sns.displot(df['41 Monetary savings'])

# %%
df.plot(kind="density",subplots=True,layout=(5,5),sharex=False,fontsize=1,figsize=(25,25))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# we have checked normal distrubution graph so none are normally distributed

# %% [markdown]
# # Encoding

# %%
#changing object dtype into numerical form
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                    1.0                  1.0
# 1                    0.0                  0.0
# 2                    0.0                  0.0
# 3                    1.0                  0.0
# 4                    0.0                  0.0
#
#    3 Which city do you shop online from?  \
# 0                                    2.0
# 1                                    2.0
# 2                                    4.0
# 3                                    6.0
# 4                                    0.0
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                         3.0
# ...

# %% [markdown]
# we have encoded data

# %%
df.shape
# Out:
# (269, 71)

# %%
df.corr()
# Out:
#                                                     1Gender of respondent  \
# 1Gender of respondent                                            1.000000
# 2 How old are you?                                               0.046169
# 3 Which city do you shop online from?                            0.080912
# 4 What is the Pin Code of where you shop online...              -0.260365
# 5 Since How Long You are Shopping Online ?                      -0.057096
# ...                                                                   ...
# Longer delivery period                                           0.060838
# Change in website/Application design                            -0.164818
# Frequent disruption when moving from one page t...              -0.256638
# Website is as efficient as before                                0.055663
# Which of the Indian online retailer would you r...              -0.003372
#
#                                                     2 How old are you?   \
# ...

# %%
#checking skewness
df.skew()
# Out:
# 1Gender of respondent                                                   0.741028
# 2 How old are you?                                                      0.680987
# 3 Which city do you shop online from?                                   0.313729
# 4 What is the Pin Code of where you shop online from?                   1.748322
# 5 Since How Long You are Shopping Online ?                             -0.276968
#                                                                           ...
# Longer delivery period                                                 -0.147702
# Change in website/Application design                                    0.354163
# Frequent disruption when moving from one page to another               -0.100608
# Website is as efficient as before                                       0.662084
# Which of the Indian online retailer would you recommend to a friend?    0.583614
# Length: 71, dtype: float64

# %% [markdown]
# # Checking outlier

# %%
#checking outlier
df.plot(kind='box', figsize=(35,30), layout=(10,8), sharex=False, subplots=True)
# Out:
# 1Gender of respondent                                                     AxesSubplot(0.125,0.816017;0.0824468x0.0639831)
# 2 How old are you?                                                      AxesSubplot(0.223936,0.816017;0.0824468x0.0639...
# 3 Which city do you shop online from?                                   AxesSubplot(0.322872,0.816017;0.0824468x0.0639...
# 4 What is the Pin Code of where you shop online from?                   AxesSubplot(0.421809,0.816017;0.0824468x0.0639...
# 5 Since How Long You are Shopping Online ?                              AxesSubplot(0.520745,0.816017;0.0824468x0.0639...
#                                                                                               ...
# Longer delivery period                                                  AxesSubplot(0.322872,0.20178;0.0824468x0.0639831)
# Change in website/Application design                                    AxesSubplot(0.421809,0.20178;0.0824468x0.0639831)
# ...

# %% [markdown]
# There is no outlier so we can proceed further

# %%
#scaling the data
from sklearn.preprocessing import StandardScaler
sc =StandardScaler()
df_scaled=sc.fit_transform(df)
df=pd.DataFrame(df_scaled, columns=df.columns)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(df_scaled,i)for i in range(df_scaled.shape[1])]
vif["features"]=df.columns
vif
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#          vif                                           features
# 0   2.206812                              1Gender of respondent
# 1   1.882311                                2 How old are you?
# 2   1.976970              3 Which city do you shop online from?
# 3   1.981756  4 What is the Pin Code of where you shop onlin...
# 4   1.715616         5 Since How Long You are Shopping Online ?
# ..       ...                                                ...
# 66       inf                             Longer delivery period
# 67       inf               Change in website/Application design
# 68       inf  Frequent disruption when moving from one page ...
# 69       inf                  Website is as efficient as before
# 70       inf  Which of the Indian online retailer would you ...
#
# ...

# %% [markdown]
# we have checked multicollinearity using vif features
